# %%
# Large cell
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
x = 42
